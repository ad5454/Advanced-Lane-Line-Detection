# %% [markdown]
# <a href="https://colab.research.google.com/github/ad5454/Adv_LaneLine_Detection/blob/main/AdvancedLaneFinding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import glob
import os
from moviepy.editor import VideoFileClip
# %matplotlib inline

# %%
### STEP 1: Camera Calibration ###

def distortion_factors():
    # Prepare object points
    # From the provided calibration images, 9*6 corners are identified
    nx = 9
    ny = 6
    objpoints = []
    imgpoints = []
    # Object points are real world points, here a 3D coordinates matrix is generated
    # z coordinates are 0 and x, y are equidistant as it is known that the chessboard is made of identical squares
    objp = np.zeros((6*9,3), np.float32)
    objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

    # Make a list of calibration images
    os.listdir("/content/drive/MyDrive/Advanced-Lane-Detection/camera_cal/")
    cal_img_list = os.listdir("/content/drive/MyDrive/Advanced-Lane-Detection/camera_cal/")

    # Imagepoints are the coresspondant object points with their coordinates in the distorted image
    # They are found in the image using the Open CV 'findChessboardCorners' function
    for image_name in cal_img_list:
        import_from = '/content/drive/MyDrive/Advanced-Lane-Detection/camera_cal/' + image_name
        img = cv2.imread(import_from)
        # Convert to grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # Find the chessboard corners
        ret, corners = cv2.findChessboardCorners(gray, (nx, ny), None)
        # If found, draw corners
        if ret == True:
            # Draw and display the corners
            #cv2.drawChessboardCorners(img, (nx, ny), corners, ret)
            imgpoints.append(corners)
            objpoints.append(objp)
    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
    #undist = cv2.undistort(img, mtx, dist, None, mtx)
    #export_to = 'camera_cal_undistorted/' + image_name
    #save the image in the destination folder
    #plt.imsave(export_to, undist)

    return mtx, dist

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### STEP 2: Perspective Transform from Car Camera to Bird's Eye View ###
mtx, dist = distortion_factors()

def warp(img):
    undist = cv2.undistort(img, mtx, dist, None, mtx)
    img_size = (img.shape[1], img.shape[0])
    offset = 300

    # Source points taken from images with straight lane lines, these are to become parallel after the warp transform
    src = np.float32([
        (190, 720), # bottom-left corner
        (596, 447), # top-left corner
        (685, 447), # top-right corner
        (1125, 720) # bottom-right corner
    ])
    # Destination points are to be parallel, taken into account the image size
    dst = np.float32([
        [offset, img_size[1]],             # bottom-left corner
        [offset, 0],                       # top-left corner
        [img_size[0]-offset, 0],           # top-right corner
        [img_size[0]-offset, img_size[1]]  # bottom-right corner
    ])
    # Calculate the transformation matrix and it's inverse transformation
    M = cv2.getPerspectiveTransform(src, dst)
    M_inv = cv2.getPerspectiveTransform(dst, src)
    warped = cv2.warpPerspective(undist, M, img_size)

    return warped, M_inv

# %%
### STEP 3: Process Binary Thresholded Images ###

#img = cv2.imread('test_images/straight_lines1.jpg')
#img = cv2.imread('test_images/straight_lines2.jpg')
#img = cv2.imread('test_images/test1.jpg')
#img = cv2.imread('test_images/test2.jpg')
#img = cv2.imread('test_images/test3.jpg')
img = cv2.imread('/content/drive/MyDrive/Advanced-Lane-Detection/test_images/test4.jpg')
#img = cv2.imread('test_images/test5.jpg')
#img = cv2.imread('test_images/test6.jpg')

def binary_thresholded(img):
    # Transform image to gray scale
    gray_img =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Apply sobel (derivative) in x direction, this is usefull to detect lines that tend to be vertical
    sobelx = cv2.Sobel(gray_img, cv2.CV_64F, 1, 0)
    abs_sobelx = np.absolute(sobelx)
    # Scale result to 0-255
    scaled_sobel = np.uint8(255*abs_sobelx/np.max(abs_sobelx))
    sx_binary = np.zeros_like(scaled_sobel)
    # Keep only derivative values that are in the margin of interest
    sx_binary[(scaled_sobel >= 30) & (scaled_sobel <= 255)] = 1

    # Detect pixels that are white in the grayscale image
    white_binary = np.zeros_like(gray_img)
    white_binary[(gray_img > 200) & (gray_img <= 255)] = 1

    # Convert image to HLS
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
    H = hls[:,:,0]
    S = hls[:,:,2]
    sat_binary = np.zeros_like(S)
    # Detect pixels that have a high saturation value
    sat_binary[(S > 90) & (S <= 255)] = 1

    hue_binary =  np.zeros_like(H)
    # Detect pixels that are yellow using the hue component
    hue_binary[(H > 10) & (H <= 25)] = 1

    # Combine all pixels detected above
    binary_1 = cv2.bitwise_or(sx_binary, white_binary)
    binary_2 = cv2.bitwise_or(hue_binary, sat_binary)
    binary = cv2.bitwise_or(binary_1, binary_2)
    #plt.imshow(binary, cmap='gray')

    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Draw figure for binary images
    #f, axarr = plt.subplots(1,6)
    #f.set_size_inches(25, 8)
    #axarr[0].imshow(img)
    #axarr[1].imshow(sx_binary, cmap='gray')
    #axarr[2].imshow(white_binary, cmap='gray')
    #axarr[3].imshow(sat_binary, cmap='gray')
    #axarr[4].imshow(hue_binary, cmap='gray')
    #axarr[5].imshow(binary, cmap='gray')
    #axarr[0].set_title("Undistorted Image")
    #axarr[1].set_title("x Sobel Derivative")
    #axarr[2].set_title("White Threshold")
    #axarr[3].set_title("Saturation Threshold")
    #axarr[4].set_title("Hue Threshold")
    #axarr[5].set_title("Combined")
    #axarr[0].axis('off')
    #axarr[1].axis('off')
    #axarr[2].axis('off')
    #axarr[3].axis('off')
    #axarr[4].axis('off')
    #axarr[5].axis('off')

    return binary

#out_img = binary_thresholded(img)

# %%
#img = cv2.imread('test_images/straight_lines1.jpg')
#img = cv2.imread('test_images/straight_lines2.jpg')
#img = cv2.imread('test_images/test1.jpg')
#img = cv2.imread('test_images/test2.jpg')
#img = cv2.imread('test_images/test3.jpg')
#img = cv2.imread('test_images/test4.jpg')
#img = cv2.imread('test_images/test5.jpg')
img = cv2.imread('/content/drive/MyDrive/Advanced-Lane-Detection/test_images/test6.jpg')

binary_thresh = binary_thresholded(img)
out_img = np.dstack((binary_thresh, binary_thresh, binary_thresh))*255
binary_warped, M_inv = warp(binary_thresh)
plt.imshow(out_img, cmap='gray')

# %%
### STEP 4: Detection of Lane Lines Using Histogram ###

def find_lane_pixels_using_histogram(binary_warped):
    # Take a histogram of the bottom half of the image
    histogram = np.sum(binary_warped[binary_warped.shape[0]//2:,:], axis=0)

    # Find the peak of the left and right halves of the histogram
    # These will be the starting point for the left and right lines
    midpoint = np.int(histogram.shape[0]//2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint

    # Choose the number of sliding windows
    nwindows = 9
    # Set the width of the windows +/- margin
    margin = 100
    # Set minimum number of pixels found to recenter window
    minpix = 50

    # Set height of windows - based on nwindows above and image shape
    window_height = np.int(binary_warped.shape[0]//nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated later for each window in nwindows
    leftx_current = leftx_base
    rightx_current = rightx_base

    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []

    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin

        # Identify the nonzero pixels in x and y within the window #
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) &
        (nonzerox >= win_xleft_low) &  (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) &
        (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]

        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)

        # If you found > minpix pixels, recenter next window on their mean position
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

    # Concatenate the arrays of indices (previously was a list of lists of pixels)
    try:
        left_lane_inds = np.concatenate(left_lane_inds)
        right_lane_inds = np.concatenate(right_lane_inds)
    except ValueError:
        # Avoids an error if the above is not implemented fully
        pass

    # Extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds]
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]

    return leftx, lefty, rightx, righty


def fit_poly(binary_warped,leftx, lefty, rightx, righty):
    ### Fit a second order polynomial to each with np.polyfit() ###
    left_fit = np.polyfit(lefty, leftx, 2)
    right_fit = np.polyfit(righty, rightx, 2)

    # Generate x and y values for plotting
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
    try:
        left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
        right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    except TypeError:
        # Avoids an error if `left` and `right_fit` are still none or incorrect
        print('The function failed to fit a line!')
        left_fitx = 1*ploty**2 + 1*ploty
        right_fitx = 1*ploty**2 + 1*ploty

    return left_fit, right_fit, left_fitx, right_fitx, ploty

def draw_poly_lines(binary_warped, left_fitx, right_fitx, ploty):
    # Create an image to draw on and an image to show the selection window
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
    window_img = np.zeros_like(out_img)

    margin = 100
    # Generate a polygon to illustrate the search window area
    # And recast the x and y points into usable format for cv2.fillPoly()
    left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
    left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin,
                              ploty])))])
    left_line_pts = np.hstack((left_line_window1, left_line_window2))
    right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
    right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin,
                              ploty])))])
    right_line_pts = np.hstack((right_line_window1, right_line_window2))

    # Draw the lane onto the warped blank image
    cv2.fillPoly(window_img, np.int_([left_line_pts]), (100, 100, 0))
    cv2.fillPoly(window_img, np.int_([right_line_pts]), (100, 100, 0))
    result = cv2.addWeighted(out_img, 1, window_img, 0.3, 0)

    # Plot the polynomial lines onto the image
    plt.plot(left_fitx, ploty, color='green')
    plt.plot(right_fitx, ploty, color='blue')
    ## End visualization steps ##
    return result

#leftx, lefty, rightx, righty = find_lane_pixels_using_histogram(binary_warped)
#left_fit, right_fit, left_fitx, right_fitx, ploty = fit_poly(binary_warped,leftx, lefty, rightx, righty)
#print(left_fit)
#out_img = draw_poly_lines(binary_warped, left_fitx, right_fitx, ploty)
#plt.imshow(out_img)

#prev_left_fit, prev_right_fit = left_fit, right_fit
#print('prev left fit: ', prev_left_fit)
#print('prev right fit: ', prev_right_fit)

# %%
### STEP 5: Detection of Lane Lines Based on Previous Step ###

#img = cv2.imread('test_images/test5.jpg')
#binary_thresh = binary_thresholded(img)
#binary_warped, M_inv = warp(binary_thresh)

# Polynomial fit values from the previous frame
# Make sure to grab the actual values from the previous step in your project!
#left_fit = np.array([ 2.13935315e-04, -3.77507980e-01,  4.76902175e+02])
#right_fit = np.array([4.17622148e-04, -4.93848953e-01,  1.11806170e+03])

def find_lane_pixels_using_prev_poly(binary_warped):
    global prev_left_fit
    global prev_right_fit
    # width of the margin around the previous polynomial to search
    margin = 100
    # Grab activated pixels
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    ### Set the area of search based on activated x-values ###
    ### within the +/- margin of our polynomial function ###
    left_lane_inds = ((nonzerox > (prev_left_fit[0]*(nonzeroy**2) + prev_left_fit[1]*nonzeroy +
                    prev_left_fit[2] - margin)) & (nonzerox < (prev_left_fit[0]*(nonzeroy**2) +
                    prev_left_fit[1]*nonzeroy + prev_left_fit[2] + margin))).nonzero()[0]
    right_lane_inds = ((nonzerox > (prev_right_fit[0]*(nonzeroy**2) + prev_right_fit[1]*nonzeroy +
                    prev_right_fit[2] - margin)) & (nonzerox < (prev_right_fit[0]*(nonzeroy**2) +
                    prev_right_fit[1]*nonzeroy + prev_right_fit[2] + margin))).nonzero()[0]
    # Again, extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds]
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]

    return leftx, lefty, rightx, righty


#leftx, lefty, rightx, righty = find_lane_pixels_using_prev_poly(binary_warped)
#left_fit, right_fit, left_fitx, right_fitx, ploty = fit_poly(binary_warped,leftx, lefty, rightx, righty)
#out_img = draw_poly_lines(binary_warped, left_fitx, right_fitx, ploty)
#plt.imshow(out_img)

# %%
### STEP 6: Calculate Vehicle Position and Curve Radius ###

def measure_curvature_meters(binary_warped, left_fitx, right_fitx, ploty):
    # Define conversions in x and y from pixels space to meters
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/700 # meters per pixel in x dimension

    left_fit_cr = np.polyfit(ploty*ym_per_pix, left_fitx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(ploty*ym_per_pix, right_fitx*xm_per_pix, 2)
    # Define y-value where we want radius of curvature
    # We'll choose the maximum y-value, corresponding to the bottom of the image
    y_eval = np.max(ploty)

    # Calculation of R_curve (radius of curvature)
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])

    return left_curverad, right_curverad

def measure_position_meters(binary_warped, left_fit, right_fit):
    # Define conversion in x from pixels space to meters
    xm_per_pix = 3.7/700 # meters per pixel in x dimension
    # Choose the y value corresponding to the bottom of the image
    y_max = binary_warped.shape[0]
    # Calculate left and right line positions at the bottom of the image
    left_x_pos = left_fit[0]*y_max**2 + left_fit[1]*y_max + left_fit[2]
    right_x_pos = right_fit[0]*y_max**2 + right_fit[1]*y_max + right_fit[2]
    # Calculate the x position of the center of the lane
    center_lanes_x_pos = (left_x_pos + right_x_pos)//2
    # Calculate the deviation between the center of the lane and the center of the picture
    # The car is assumed to be placed in the center of the picture
    # If the deviation is negative, the car is on the felt hand side of the center of the lane
    veh_pos = ((binary_warped.shape[1]//2) - center_lanes_x_pos) * xm_per_pix
    return veh_pos

#left_curverad, right_curverad =  measure_curvature_meters(binary_warped, left_fitx, right_fitx, ploty)
#print('left curve radius in meters  = ', left_curverad)
#print('right curve radius in meters = ', right_curverad)
#veh_pos = measure_position_meters(binary_warped, left_fit, right_fit)
#print('vehicle position relative to center  = ', veh_pos)

# %%
### STEP 7: Project Lane Delimitations Back on Image Plane and Add Text for Lane Info ###

def project_lane_info(img, binary_warped, ploty, left_fitx, right_fitx, M_inv, left_curverad, right_curverad, veh_pos):
    # Create an image to draw the lines on
    warp_zero = np.zeros_like(binary_warped).astype(np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

    # Recast the x and y points into usable format for cv2.fillPoly()
    pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
    pts = np.hstack((pts_left, pts_right))

    # Draw the lane onto the warped blank image
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

    # Warp the blank back to original image space using inverse perspective matrix (Minv)
    newwarp = cv2.warpPerspective(color_warp, M_inv, (img.shape[1], img.shape[0]))

    # Combine the result with the original image
    out_img = cv2.addWeighted(img, 1, newwarp, 0.3, 0)

    cv2.putText(out_img,'Curve Radius [m]: '+str((left_curverad+right_curverad)/2)[:7],(40,70), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1.6, (255,255,255),2,cv2.LINE_AA)
    cv2.putText(out_img,'Center Offset [m]: '+str(veh_pos)[:7],(40,150), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1.6,(255,255,255),2,cv2.LINE_AA)

    return out_img

#new_img = project_lane_info(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), binary_warped, ploty, left_fitx, right_fitx, M_inv, left_curverad, right_curverad, veh_pos)

# Plot the result
#f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
#f.tight_layout()
#ax1.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#ax1.set_title('Original Image', fontsize=20)
#ax2.imshow(new_img, cmap='gray')
#ax2.set_title('Image With Lane Marked', fontsize=20)

# %%
global left_fit_hist
left_fit_hist = np.array([])
#print(len(left_fit_hist))

global right_fit_hist
right_fit_hist = np.array([])

#left_fit = [1.3, 4.5, 6.7]
#left_fit_hist = np.array(left_fit)
#print(len(left_fit_hist))
#left_fit = [2.3, 5.5, 9.7]
#new_fit = np.array(left_fit)
#left_fit_hist = np.vstack([left_fit_hist, new_fit])
#left_fit = [8.3, 3.5, 21.7]
#new_fit = np.array(left_fit)
#left_fit_hist = np.vstack([left_fit_hist, new_fit])
#print(left_fit_hist)
#print(len(left_fit_hist))
#prev_left_fit = [np.mean(left_fit_hist[:,0]), np.mean(left_fit_hist[:,1]), np.mean(left_fit_hist[:,2])]
#left_fit_hist = np.delete(left_fit_hist, 0,0)

#print(left_fit_hist)
#print(prev_left_fit)

# %%
### STEP 8: Lane Finding Pipeline on Video ###

def lane_finding_pipeline(img):
    global left_fit_hist
    global right_fit_hist
    global prev_left_fit
    global prev_right_fit
    binary_thresh = binary_thresholded(img)
    binary_warped, M_inv = warp(binary_thresh)
    #out_img = np.dstack((binary_thresh, binary_thresh, binary_thresh))*255
    if (len(left_fit_hist) == 0):
        leftx, lefty, rightx, righty = find_lane_pixels_using_histogram(binary_warped)
        left_fit, right_fit, left_fitx, right_fitx, ploty = fit_poly(binary_warped,leftx, lefty, rightx, righty)
        # Store fit in history
        left_fit_hist = np.array(left_fit)
        new_left_fit = np.array(left_fit)
        left_fit_hist = np.vstack([left_fit_hist, new_left_fit])
        right_fit_hist = np.array(right_fit)
        new_right_fit = np.array(right_fit)
        right_fit_hist = np.vstack([right_fit_hist, new_right_fit])
    else:
        prev_left_fit = [np.mean(left_fit_hist[:,0]), np.mean(left_fit_hist[:,1]), np.mean(left_fit_hist[:,2])]
        prev_right_fit = [np.mean(right_fit_hist[:,0]), np.mean(right_fit_hist[:,1]), np.mean(right_fit_hist[:,2])]
        leftx, lefty, rightx, righty = find_lane_pixels_using_prev_poly(binary_warped)
        if (len(lefty) == 0 or len(righty) == 0):
            leftx, lefty, rightx, righty = find_lane_pixels_using_histogram(binary_warped)
        left_fit, right_fit, left_fitx, right_fitx, ploty = fit_poly(binary_warped,leftx, lefty, rightx, righty)

        # Add new values to history
        new_left_fit = np.array(left_fit)
        left_fit_hist = np.vstack([left_fit_hist, new_left_fit])
        new_right_fit = np.array(right_fit)
        right_fit_hist = np.vstack([right_fit_hist, new_right_fit])

        # Remove old values from history
        if (len(left_fit_hist) > 10):
            left_fit_hist = np.delete(left_fit_hist, 0,0)
            right_fit_hist = np.delete(right_fit_hist, 0,0)

    left_curverad, right_curverad =  measure_curvature_meters(binary_warped, left_fitx, right_fitx, ploty)
                                     #measure_curvature_meters(binary_warped, left_fitx, right_fitx, ploty)
    veh_pos = measure_position_meters(binary_warped, left_fit, right_fit)
    out_img = project_lane_info(img, binary_warped, ploty, left_fitx, right_fitx, M_inv, left_curverad, right_curverad, veh_pos)
    return out_img

video_output = '/content/drive/MyDrive/Advanced-Lane-Detection/project_video_output.mp4'
clip1 = VideoFileClip("/content/drive/MyDrive/Advanced-Lane-Detection/project_video.mp4")
output_clip = clip1.fl_image(lane_finding_pipeline)
# %time output_clip.write_videofile(video_output, audio=False)
# Out:
# Moviepy - Building video /content/drive/MyDrive/Advanced-Lane-Detection/project_video_output_01.mp4.
# Moviepy - Writing video /content/drive/MyDrive/Advanced-Lane-Detection/project_video_output_01.mp4
# t:  50%|█████     | 1410/2814 [10:14<07:44,  3.02it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1409/2814, at time 23.48/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1411/2814 [10:14<07:34,  3.08it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1410/2814, at time 23.50/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1412/2814 [10:15<07:37,  3.07it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1411/2814, at time 23.52/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1413/2814 [10:15<08:01,  2.91it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1412/2814, at time 23.53/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1414/2814 [10:15<07:57,  2.93it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1413/2814, at time 23.55/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1415/2814 [10:16<07:56,  2.94it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1414/2814, at time 23.57/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1416/2814 [10:16<07:50,  2.97it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1415/2814, at time 23.58/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1417/2814 [10:16<08:03,  2.89it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1416/2814, at time 23.60/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1418/2814 [10:17<08:10,  2.84it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1417/2814, at time 23.62/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1419/2814 [10:17<08:10,  2.85it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1418/2814, at time 23.63/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1420/2814 [10:17<07:57,  2.92it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1419/2814, at time 23.65/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 1421/2814 [10:18<08:14,  2.82it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1420/2814, at time 23.67/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1422/2814 [10:18<08:13,  2.82it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1421/2814, at time 23.68/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1423/2814 [10:19<08:27,  2.74it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1422/2814, at time 23.70/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1424/2814 [10:19<09:21,  2.47it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1423/2814, at time 23.72/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1425/2814 [10:20<10:13,  2.26it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1424/2814, at time 23.73/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1426/2814 [10:20<10:56,  2.11it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1425/2814, at time 23.75/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1427/2814 [10:21<12:04,  1.91it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1426/2814, at time 23.77/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1428/2814 [10:21<12:32,  1.84it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1427/2814, at time 23.78/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1429/2814 [10:22<12:26,  1.86it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1428/2814, at time 23.80/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1430/2814 [10:22<12:11,  1.89it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1429/2814, at time 23.82/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1431/2814 [10:23<12:39,  1.82it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1430/2814, at time 23.83/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1432/2814 [10:24<12:59,  1.77it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1431/2814, at time 23.85/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1433/2814 [10:24<12:53,  1.79it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1432/2814, at time 23.87/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1434/2814 [10:25<12:29,  1.84it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1433/2814, at time 23.88/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1435/2814 [10:25<13:21,  1.72it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1434/2814, at time 23.90/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1436/2814 [10:26<13:16,  1.73it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1435/2814, at time 23.92/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1437/2814 [10:26<11:50,  1.94it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1436/2814, at time 23.93/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1438/2814 [10:27<10:48,  2.12it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1437/2814, at time 23.95/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1439/2814 [10:27<09:53,  2.32it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1438/2814, at time 23.97/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1440/2814 [10:27<09:11,  2.49it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1439/2814, at time 23.98/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1441/2814 [10:28<08:49,  2.59it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1440/2814, at time 24.00/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████     | 1442/2814 [10:28<08:23,  2.72it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1441/2814, at time 24.02/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████▏    | 1443/2814 [10:28<07:55,  2.88it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1442/2814, at time 24.03/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████▏    | 1444/2814 [10:29<07:34,  3.01it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1443/2814, at time 24.05/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████▏    | 1445/2814 [10:29<07:41,  2.97it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1444/2814, at time 24.07/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████▏    | 1446/2814 [10:29<07:23,  3.08it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1445/2814, at time 24.08/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████▏    | 1447/2814 [10:30<07:15,  3.14it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1446/2814, at time 24.10/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████▏    | 1448/2814 [10:30<07:09,  3.18it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1447/2814, at time 24.12/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  51%|█████▏    | 1449/2814 [10:30<07:19,  3.10it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1448/2814, at time 24.13/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1450/2814 [10:30<07:10,  3.17it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1449/2814, at time 24.15/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1451/2814 [10:31<07:28,  3.04it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1450/2814, at time 24.17/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1452/2814 [10:31<07:19,  3.10it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1451/2814, at time 24.18/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1453/2814 [10:32<07:41,  2.95it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1452/2814, at time 24.20/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1454/2814 [10:32<07:43,  2.93it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1453/2814, at time 24.22/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1455/2814 [10:32<07:23,  3.06it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1454/2814, at time 24.23/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1456/2814 [10:32<07:10,  3.16it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1455/2814, at time 24.25/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1457/2814 [10:33<07:05,  3.19it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1456/2814, at time 24.27/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1458/2814 [10:33<07:00,  3.22it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1457/2814, at time 24.28/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1459/2814 [10:33<06:45,  3.34it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1458/2814, at time 24.30/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1460/2814 [10:34<06:32,  3.45it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1459/2814, at time 24.32/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1461/2814 [10:34<06:36,  3.41it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1460/2814, at time 24.33/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1462/2814 [10:34<06:32,  3.44it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1461/2814, at time 24.35/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1463/2814 [10:34<06:28,  3.48it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1462/2814, at time 24.37/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1464/2814 [10:35<06:33,  3.43it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1463/2814, at time 24.38/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1465/2814 [10:35<06:49,  3.29it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1464/2814, at time 24.40/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1466/2814 [10:35<06:55,  3.24it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1465/2814, at time 24.42/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1467/2814 [10:36<06:55,  3.24it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1466/2814, at time 24.43/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1468/2814 [10:36<07:11,  3.12it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1467/2814, at time 24.45/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1469/2814 [10:37<08:10,  2.74it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1468/2814, at time 24.47/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1470/2814 [10:37<08:39,  2.59it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1469/2814, at time 24.48/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1471/2814 [10:38<09:33,  2.34it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1470/2814, at time 24.50/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1472/2814 [10:38<09:51,  2.27it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1471/2814, at time 24.52/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1473/2814 [10:38<10:02,  2.23it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1472/2814, at time 24.53/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1474/2814 [10:39<10:01,  2.23it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1473/2814, at time 24.55/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1475/2814 [10:39<10:16,  2.17it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1474/2814, at time 24.57/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1476/2814 [10:40<09:57,  2.24it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1475/2814, at time 24.58/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  52%|█████▏    | 1477/2814 [10:40<10:22,  2.15it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1476/2814, at time 24.60/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1478/2814 [10:41<10:40,  2.09it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1477/2814, at time 24.62/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1479/2814 [10:41<10:53,  2.04it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1478/2814, at time 24.63/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1480/2814 [10:42<10:48,  2.06it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1479/2814, at time 24.65/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1481/2814 [10:42<10:52,  2.04it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1480/2814, at time 24.67/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1482/2814 [10:43<10:20,  2.15it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1481/2814, at time 24.68/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1483/2814 [10:43<10:00,  2.22it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1482/2814, at time 24.70/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1484/2814 [10:44<09:58,  2.22it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1483/2814, at time 24.72/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1485/2814 [10:44<09:00,  2.46it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1484/2814, at time 24.73/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1486/2814 [10:44<08:08,  2.72it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1485/2814, at time 24.75/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1487/2814 [10:44<07:38,  2.89it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1486/2814, at time 24.77/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1488/2814 [10:45<07:07,  3.10it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1487/2814, at time 24.78/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1489/2814 [10:45<07:03,  3.13it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1488/2814, at time 24.80/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1490/2814 [10:45<07:04,  3.12it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1489/2814, at time 24.82/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1491/2814 [10:46<06:53,  3.20it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1490/2814, at time 24.83/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1492/2814 [10:46<06:40,  3.30it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1491/2814, at time 24.85/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1493/2814 [10:46<06:42,  3.28it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1492/2814, at time 24.87/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1494/2814 [10:47<06:35,  3.34it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1493/2814, at time 24.88/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1495/2814 [10:47<06:23,  3.44it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1494/2814, at time 24.90/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1496/2814 [10:47<06:19,  3.48it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1495/2814, at time 24.92/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1497/2814 [10:47<06:20,  3.46it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1496/2814, at time 24.93/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1498/2814 [10:48<06:23,  3.43it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1497/2814, at time 24.95/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1499/2814 [10:48<06:20,  3.46it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1498/2814, at time 24.97/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1500/2814 [10:48<06:23,  3.43it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1499/2814, at time 24.98/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1501/2814 [10:49<06:22,  3.43it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1500/2814, at time 25.00/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1502/2814 [10:49<06:19,  3.45it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1501/2814, at time 25.02/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1503/2814 [10:49<06:19,  3.46it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1502/2814, at time 25.03/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1504/2814 [10:49<06:24,  3.41it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1503/2814, at time 25.05/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  53%|█████▎    | 1505/2814 [10:50<06:39,  3.28it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1504/2814, at time 25.07/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▎    | 1506/2814 [10:50<06:40,  3.27it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1505/2814, at time 25.08/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▎    | 1507/2814 [10:50<06:42,  3.25it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1506/2814, at time 25.10/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▎    | 1508/2814 [10:51<06:49,  3.19it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1507/2814, at time 25.12/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▎    | 1509/2814 [10:51<06:45,  3.21it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1508/2814, at time 25.13/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▎    | 1510/2814 [10:51<06:48,  3.19it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1509/2814, at time 25.15/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▎    | 1511/2814 [10:52<06:51,  3.17it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1510/2814, at time 25.17/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▎    | 1512/2814 [10:52<06:41,  3.24it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1511/2814, at time 25.18/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▍    | 1513/2814 [10:52<06:39,  3.26it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1512/2814, at time 25.20/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  54%|█████▍    | 1514/2814 [10:53<06:32,  3.31it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 1513/2814, at time 25.22/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# ...
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2781/2814 [18:50<00:15,  2.07it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2780/2814, at time 46.33/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2782/2814 [18:50<00:15,  2.05it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2781/2814, at time 46.35/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2783/2814 [18:51<00:15,  2.03it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2782/2814, at time 46.37/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2784/2814 [18:51<00:14,  2.05it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2783/2814, at time 46.38/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2785/2814 [18:52<00:14,  2.01it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2784/2814, at time 46.40/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2786/2814 [18:52<00:13,  2.03it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2785/2814, at time 46.42/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2787/2814 [18:53<00:13,  2.04it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2786/2814, at time 46.43/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2788/2814 [18:53<00:12,  2.08it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2787/2814, at time 46.45/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2789/2814 [18:54<00:12,  2.00it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2788/2814, at time 46.47/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2790/2814 [18:54<00:11,  2.05it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2789/2814, at time 46.48/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2791/2814 [18:54<00:10,  2.20it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2790/2814, at time 46.50/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2792/2814 [18:55<00:09,  2.34it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2791/2814, at time 46.52/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2793/2814 [18:55<00:08,  2.43it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2792/2814, at time 46.53/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2794/2814 [18:56<00:08,  2.41it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2793/2814, at time 46.55/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2795/2814 [18:56<00:07,  2.47it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2794/2814, at time 46.57/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2796/2814 [18:56<00:07,  2.55it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2795/2814, at time 46.58/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2797/2814 [18:57<00:06,  2.72it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2796/2814, at time 46.60/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2798/2814 [18:57<00:05,  2.72it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2797/2814, at time 46.62/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 2799/2814 [18:57<00:05,  2.74it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2798/2814, at time 46.63/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2800/2814 [18:58<00:04,  2.82it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2799/2814, at time 46.65/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2801/2814 [18:58<00:04,  2.86it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2800/2814, at time 46.67/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2802/2814 [18:58<00:04,  2.92it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2801/2814, at time 46.68/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2803/2814 [18:59<00:03,  2.85it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2802/2814, at time 46.70/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2804/2814 [18:59<00:03,  2.82it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2803/2814, at time 46.72/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2805/2814 [18:59<00:03,  2.78it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2804/2814, at time 46.73/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2806/2814 [19:00<00:02,  2.83it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2805/2814, at time 46.75/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2807/2814 [19:00<00:02,  2.76it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2806/2814, at time 46.77/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2808/2814 [19:01<00:02,  2.75it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2807/2814, at time 46.78/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2809/2814 [19:01<00:01,  2.75it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2808/2814, at time 46.80/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2810/2814 [19:01<00:01,  2.78it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2809/2814, at time 46.82/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2811/2814 [19:02<00:01,  2.77it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2810/2814, at time 46.83/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2812/2814 [19:02<00:00,  2.78it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2811/2814, at time 46.85/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 2813/2814 [19:02<00:00,  2.75it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2812/2814, at time 46.87/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|██████████| 2814/2814 [19:03<00:00,  2.74it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/Advanced-Lane-Detection/Media Player 2023-08-03 18-00-16.mp4, 6220800 bytes wanted but 0 bytes read,at frame 2813/2814, at time 46.88/46.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/Advanced-Lane-Detection/project_video_output_01.mp4
# CPU times: user 16min 11s, sys: 1min 46s, total: 17min 57s
# Wall time: 19min 4s
